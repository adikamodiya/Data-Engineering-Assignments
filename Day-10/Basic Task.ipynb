-- %% [markdown]
-- # Question 1
-- Create a serverless SQL warehouse and run 3 exploratory queries against a gold table from Day 6/8.

-- %%
select * from dev.gold.aov_by_segment;

-- %%
select * from dev.gold.best_selling_products_by_category
where total_sale > 467219.34 ;

-- %%
select * from dev.gold.supplier_performance_metrics;

-- %% [markdown]
-- # Question 2
-- Build an AI/BI dashboard with at least 2 visualizations sourced from those queries.

-- %% [markdown]
-- ![image_1789369447300.png](./image_1789369447300.png "image_1789369447300.png")

-- %% [markdown]
-- # Question 3
--
-- Publish the dashboard and test the 'Ask Genie' feature with 2 plain-English questions.

-- %% [markdown]
-- Question Asked -  what is top region sales wise? || Ans - south
--
-- Question Asked - what is the total sale year wise? || Ans - 2024 - 20 M , 2025- 52 M , 2026 - 30 M
