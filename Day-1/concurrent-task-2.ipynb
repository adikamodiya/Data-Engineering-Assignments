-- %%
-- insert into  dev.demo.products_demo(product_name,category,price,segment)
-- values('lifeboy-handwash' , 'Household', 200.00, 'Basic')

insert into  dev.demo.products_demo(product_name,category,price,segment)
values('lifeboy-soap' , 'Household', 110.00, 'Basic')
