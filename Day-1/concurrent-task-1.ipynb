-- %%
insert into  dev.demo.products_demo(product_name,category,price,segment)
values('detol-handwash' , 'Household', 100.00, 'Basic')



-- alter table dev.demo.products_demo  
-- rename column price to price_new

-- %%
-- ALTER TABLE dev.demo.products_demo SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name')

-- %%
desc history dev.demo.products_demo
