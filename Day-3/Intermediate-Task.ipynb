-- %% [markdown]
-- # Question 4

-- %%
CREATE OR REPLACE TABLE cyntexa_dev.sales.sales_table AS 
SELECT 
  *, 
  _metadata.file_path AS file_path, 
  _metadata.file_modification_time AS ingestion_time 
FROM read_files('/Volumes/cyntexa_dev/sales/my_volume/*.csv');

-- %%
select * from cyntexa_dev.sales.sales_table

-- %% [markdown]
-- # Question 5

-- %%
CREATE OR REPLACE TABLE cyntexa_dev.sales.sales_table_iceberg USING Iceberg AS 
SELECT 
  *, 
  _metadata.file_path AS file_path, 
  _metadata.file_modification_time AS ingestion_time 
FROM read_files('/Volumes/cyntexa_dev/sales/my_volume/*.csv')   ;

-- %%
select * from cyntexa_dev.sales.sales_table_iceberg

-- %%
desc detail cyntexa_dev.sales.sales_table_iceberg

-- %%
desc detail cyntexa_dev.sales.sales_table;

-- %% [markdown]
-- - Details for both files are same , only format is different
-- - common - created at , description,lastmodified, numfiles,sizeBytes ,etc..

-- %% [markdown]
-- # Question 6

-- %%
CREATE OR REPLACE TABLE cyntexa_dev.sales.sales_table AS 
SELECT 
  *, 
  _metadata.file_path AS file_path, 
  _metadata.file_modification_time AS ingestion_time 
FROM read_files('/Volumes/cyntexa_dev/sales/my_volume/*.csv');

-- %%
select  file_path,ingestion_time, count(*) as record_count from cyntexa_dev.sales.sales_table group by file_path,ingestion_time
