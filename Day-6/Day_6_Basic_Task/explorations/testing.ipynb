-- %%
%python
df = spark.read.table('cyntexa_dev.medallion_day_6.bronze_sales')
df.columns

-- %%
select * from cyntexa_dev.medallion_day_6.bronze_sales  where source_file ='sales2.csv'

-- %%
desc table cyntexa_dev.medallion_day_6.bronze_sales

-- %%
desc table cyntexa_dev.medallion_day_6.silver_sales

-- %%
select * from cyntexa_dev.medallion_day_6.silver_sales

-- %%
select * from cyntexa_dev.medallion_day_6.gold_sales_total_revenue_per_customers

-- %%
desc table  cyntexa_dev.medallion_day_6.gold_sales_total_revenue_per_customers
